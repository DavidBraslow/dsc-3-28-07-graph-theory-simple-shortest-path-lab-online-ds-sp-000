# %% [markdown]
# # Graph Theory: Simple and Shortest Paths - Lab

# %% [markdown]
# ## Introduction
# In this lab, we shall work with Florentine families graph.
# [Click here to see details on Florantine family dataset](http://www.casos.cs.cmu.edu/computational_tools/datasets/external/padgett/index2.html). This dataset comes bundled with networkx [as shown here](https://networkx.github.io/documentation/stable/reference/generated/networkx.generators.social.florentine_families_graph.html#networkx.generators.social.florentine_families_graph). Visit these links to get some idea about the contents of this dataset. We shall use it as an undirected dataset for this lab and work on identifying paths between different nodes.
# <img src="http://www.promoguidesiena.it/admin/img/022013/1362048286CaterinaDeMediciweddinguffizi5470.jpg" width=300>
#
# ## Objectives
# You will be able to:
# - Load and study Florentine families graph generator in networkx
# - Calculate and visualize the different paths between a given set of nodes

# %% [markdown]
# ### Load and Draw Florentine families graph generator with a Fruchterman Reingold layout
#
# Note: Refer to the documentation for methods to load the required graph and layout.

# %%
# Your code here 
import networkx as nx
import matplotlib.pyplot as plt

GA = nx.generators.social.florentine_families_graph()
print(GA.nodes())
nx.draw(GA, with_labels=True)
plt.show()
# Out:
# ['Acciaiuoli', 'Medici', 'Castellani', 'Peruzzi', 'Strozzi', 'Barbadori', 'Ridolfi', 'Tornabuoni', 'Albizzi', 'Salviati', 'Pazzi', 'Bischeri', 'Guadagni', 'Ginori', 'Lamberteschi']

# %% [markdown]
# ### Calculate shortest path between Medici and Peruzzi families

# %%
# Your code here 
nx.shortest_path(GA, 'Medici', 'Peruzzi')
# Out:
# ['Medici', 'Barbadori', 'Castellani', 'Peruzzi']

# %% [markdown]
# You will see above that the shortest paths may not necessarily be unique i.e. there can be more than one , while counting the number of hops. We can use `all_shortest_paths()` method to find if there are more than one.
#
# ### Calculate all shortest paths between Medici and Peruzzi families

# %%
# Your code here 
list(nx.all_shortest_paths(GA, 'Medici', 'Peruzzi'))
# Out:
# [['Medici', 'Barbadori', 'Castellani', 'Peruzzi'],
#  ['Medici', 'Ridolfi', 'Strozzi', 'Peruzzi']]

# %% [markdown]
# ### Calculate and draw the shortest path between Lamberteschi and Ridolfi families
#
# - Create a function plot_paths(G, paths) that would take in a graph with calculated path(s)
# - Use `fruchterman_reingold_layout()`
# - For all paths in `paths`, color the edges and display the graph
# - Print the path in the output

# %%
source = 'Lamberteschi'
target = 'Ridolfi'

# %%
def plot_paths(G, paths):
    # Your code here 
    layout = nx.fruchterman_reingold_layout(G)
    path_tuples = []
    for path in paths:
        for i in range(0, len(path)-1):
            path_tuples.append((path[i], path[i+1]))
            path_tuples.append((path[i+1], path[i]))

    print(path_tuples)
    edge_colors = []
    widths = []
    for edge in G.edges():
        print(edge)
        if edge in path_tuples:
            edge_colors.append('salmon')
            widths.append(3)
        else:
            edge_colors.append('black')
            widths.append(1)
    nx.draw(G, pos = layout, with_labels=True, edge_color=edge_colors, width = widths)
    
print(nx.shortest_path(GA, source, target))
plot_paths(GA, [nx.shortest_path(GA, source, target)])
# Out:
# ['Lamberteschi', 'Guadagni', 'Tornabuoni', 'Ridolfi']
# [('Lamberteschi', 'Guadagni'), ('Guadagni', 'Lamberteschi'), ('Guadagni', 'Tornabuoni'), ('Tornabuoni', 'Guadagni'), ('Tornabuoni', 'Ridolfi'), ('Ridolfi', 'Tornabuoni')]
# ('Acciaiuoli', 'Medici')
# ('Medici', 'Barbadori')
# ('Medici', 'Ridolfi')
# ('Medici', 'Tornabuoni')
# ('Medici', 'Albizzi')
# ('Medici', 'Salviati')
# ('Castellani', 'Peruzzi')
# ('Castellani', 'Strozzi')
# ('Castellani', 'Barbadori')
# ('Peruzzi', 'Strozzi')
# ('Peruzzi', 'Bischeri')
# ('Strozzi', 'Ridolfi')
# ('Strozzi', 'Bischeri')
# ('Ridolfi', 'Tornabuoni')
# ('Tornabuoni', 'Guadagni')
# ('Albizzi', 'Ginori')
# ('Albizzi', 'Guadagni')
# ('Salviati', 'Pazzi')
# ('Bischeri', 'Guadagni')
# ('Guadagni', 'Lamberteschi')

# %% [markdown]
# ### Calculate and draw all simple paths between Lamberteschi and Ridolfi families
# - Use `nx.all_simple_paths(G, source, target)` to calculate all possible paths between two families and plot them.

# %%
# Your code here 
paths = nx.all_simple_paths(GA, source, target)
plot_paths(GA, paths)
# Out:
# [('Lamberteschi', 'Guadagni'), ('Guadagni', 'Lamberteschi'), ('Guadagni', 'Tornabuoni'), ('Tornabuoni', 'Guadagni'), ('Tornabuoni', 'Medici'), ('Medici', 'Tornabuoni'), ('Medici', 'Barbadori'), ('Barbadori', 'Medici'), ('Barbadori', 'Castellani'), ('Castellani', 'Barbadori'), ('Castellani', 'Peruzzi'), ('Peruzzi', 'Castellani'), ('Peruzzi', 'Strozzi'), ('Strozzi', 'Peruzzi'), ('Strozzi', 'Ridolfi'), ('Ridolfi', 'Strozzi'), ('Lamberteschi', 'Guadagni'), ('Guadagni', 'Lamberteschi'), ('Guadagni', 'Tornabuoni'), ('Tornabuoni', 'Guadagni'), ('Tornabuoni', 'Medici'), ('Medici', 'Tornabuoni'), ('Medici', 'Barbadori'), ('Barbadori', 'Medici'), ('Barbadori', 'Castellani'), ('Castellani', 'Barbadori'), ('Castellani', 'Peruzzi'), ('Peruzzi', 'Castellani'), ('Peruzzi', 'Bischeri'), ('Bischeri', 'Peruzzi'), ('Bischeri', 'Strozzi'), ('Strozzi', 'Bischeri'), ('Strozzi', 'Ridolfi'), ('Ridolfi', 'Strozzi'), ('Lamberteschi', 'Guadagni'), ('Guadagni', 'Lamberteschi'), ('Guadagni', 'Tornabuoni'), ('Tornabuoni', 'Guadagni'), ('Tornabuoni', 'Medici'), ('Medici', 'Tornabuoni'), ('Medici', 'Barbadori'), ('Barbadori', 'Medici'), ('Barbadori', 'Castellani'), ('Castellani', 'Barbadori'), ('Castellani', 'Strozzi'), ('Strozzi', 'Castellani'), ('Strozzi', 'Ridolfi'), ('Ridolfi', 'Strozzi'), ('Lamberteschi', 'Guadagni'), ('Guadagni', 'Lamberteschi'), ('Guadagni', 'Tornabuoni'), ('Tornabuoni', 'Guadagni'), ('Tornabuoni', 'Medici'), ('Medici', 'Tornabuoni'), ('Medici', 'Ridolfi'), ('Ridolfi', 'Medici'), ('Lamberteschi', 'Guadagni'), ('Guadagni', 'Lamberteschi'), ('Guadagni', 'Tornabuoni'), ('Tornabuoni', 'Guadagni'), ('Tornabuoni', 'Ridolfi'), ('Ridolfi', 'Tornabuoni'), ('Lamberteschi', 'Guadagni'), ('Guadagni', 'Lamberteschi'), ('Guadagni', 'Albizzi'), ('Albizzi', 'Guadagni'), ('Albizzi', 'Medici'), ('Medici', 'Albizzi'), ('Medici', 'Barbadori'), ('Barbadori', 'Medici'), ('Barbadori', 'Castellani'), ('Castellani', 'Barbadori'), ('Castellani', 'Peruzzi'), ('Peruzzi', 'Castellani'), ('Peruzzi', 'Strozzi'), ('Strozzi', 'Peruzzi'), ('Strozzi', 'Ridolfi'), ('Ridolfi', 'Strozzi'), ('Lamberteschi', 'Guadagni'), ('Guadagni', 'Lamberteschi'), ('Guadagni', 'Albizzi'), ('Albizzi', 'Guadagni'), ('Albizzi', 'Medici'), ('Medici', 'Albizzi'), ('Medici', 'Barbadori'), ('Barbadori', 'Medici'), ('Barbadori', 'Castellani'), ('Castellani', 'Barbadori'), ('Castellani', 'Peruzzi'), ('Peruzzi', 'Castellani'), ('Peruzzi', 'Bischeri'), ('Bischeri', 'Peruzzi'), ('Bischeri', 'Strozzi'), ('Strozzi', 'Bischeri'), ('Strozzi', 'Ridolfi'), ('Ridolfi', 'Strozzi'), ('Lamberteschi', 'Guadagni'), ('Guadagni', 'Lamberteschi'), ('Guadagni', 'Albizzi'), ('Albizzi', 'Guadagni'), ('Albizzi', 'Medici'), ('Medici', 'Albizzi'), ('Medici', 'Barbadori'), ('Barbadori', 'Medici'), ('Barbadori', 'Castellani'), ('Castellani', 'Barbadori'), ('Castellani', 'Strozzi'), ('Strozzi', 'Castellani'), ('Strozzi', 'Ridolfi'), ('Ridolfi', 'Strozzi'), ('Lamberteschi', 'Guadagni'), ('Guadagni', 'Lamberteschi'), ('Guadagni', 'Albizzi'), ('Albizzi', 'Guadagni'), ('Albizzi', 'Medici'), ('Medici', 'Albizzi'), ('Medici', 'Ridolfi'), ('Ridolfi', 'Medici'), ('Lamberteschi', 'Guadagni'), ('Guadagni', 'Lamberteschi'), ('Guadagni', 'Albizzi'), ('Albizzi', 'Guadagni'), ('Albizzi', 'Medici'), ('Medici', 'Albizzi'), ('Medici', 'Tornabuoni'), ('Tornabuoni', 'Medici'), ('Tornabuoni', 'Ridolfi'), ('Ridolfi', 'Tornabuoni'), ('Lamberteschi', 'Guadagni'), ('Guadagni', 'Lamberteschi'), ('Guadagni', 'Bischeri'), ('Bischeri', 'Guadagni'), ('Bischeri', 'Peruzzi'), ('Peruzzi', 'Bischeri'), ('Peruzzi', 'Castellani'), ('Castellani', 'Peruzzi'), ('Castellani', 'Strozzi'), ('Strozzi', 'Castellani'), ('Strozzi', 'Ridolfi'), ('Ridolfi', 'Strozzi'), ('Lamberteschi', 'Guadagni'), ('Guadagni', 'Lamberteschi'), ('Guadagni', 'Bischeri'), ('Bischeri', 'Guadagni'), ('Bischeri', 'Peruzzi'), ('Peruzzi', 'Bischeri'), ('Peruzzi', 'Castellani'), ('Castellani', 'Peruzzi'), ('Castellani', 'Barbadori'), ('Barbadori', 'Castellani'), ('Barbadori', 'Medici'), ('Medi ...
# ('Acciaiuoli', 'Medici')
# ('Medici', 'Barbadori')
# ('Medici', 'Ridolfi')
# ('Medici', 'Tornabuoni')
# ('Medici', 'Albizzi')
# ('Medici', 'Salviati')
# ('Castellani', 'Peruzzi')
# ('Castellani', 'Strozzi')
# ('Castellani', 'Barbadori')
# ('Peruzzi', 'Strozzi')
# ('Peruzzi', 'Bischeri')
# ('Strozzi', 'Ridolfi')
# ('Strozzi', 'Bischeri')
# ('Ridolfi', 'Tornabuoni')
# ('Tornabuoni', 'Guadagni')
# ('Albizzi', 'Ginori')
# ('Albizzi', 'Guadagni')
# ('Salviati', 'Pazzi')
# ('Bischeri', 'Guadagni')
# ('Guadagni', 'Lamberteschi')

# %% [markdown]
# ## Level Up - Optional
#
# - Modify the `plot_paths()` to show each path in a different graph, with edge width showing the **distance** between source and target.
#
# - Prettify the graph entities further in order to make it more presentable

# %% [markdown]
# ## Summary
#
# In this lab, we saw how to calculate and visualize paths between a given set of nodes in a graph. The skills learned in these simple exercises can be scaled to deal with much larger networks with possible tens of thousands of nodes (or maybe more) to identify paths between node entities. We mainly looked at calculating the simple distance, but the idea can be applied to directed and weighted networks with same level of ease.
